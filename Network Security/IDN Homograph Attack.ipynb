# %% [markdown]
# # IDN Homograph Attack

# %% [markdown]
# การโจมตีด้วยวิธีการ IDN Homograph Attack เป็นการทำหน้าเว็บปลอม และจดชื่อโดเมนที่คล้ายกันโดยใช้ Unicode Character ทำให้ผู้ใช้งานไม่ทันสังเกต ซึ่งทาง Facebook ได้มีเครื่องมือ [Certificate Transparency Monitoring](https://developers.facebook.com/tools/ct/) เพื่อใช้ในการตรวจสอบโดเมนที่คล้ายกัน ซึ่งจะไปอ่านข้อมูลจาก Certificate Transparency Log

# %%
! git clone https://github.com/UndeadSec/EvilURL.git
# Out:
# Cloning into 'EvilURL'...
# remote: Enumerating objects: 132, done.
# remote: Total 132 (delta 0), reused 0 (delta 0), pack-reused 132
# Receiving objects: 100% (132/132), 1.18 MiB | 25.75 MiB/s, done.
# Resolving deltas: 100% (64/64), done.

# %%
% cd /content/EvilURL
# Out:
# /content/EvilURL

# %%
! python3 evilurl.py
# Out:
#
# 88888888888           88  88  88        88  88888888ba   88
# 88                    ""  88  88        88  88      "8b  88
# 88                        88  88        88  88      ,8P  88
# 88aaaaa  8b       d8  88  88  88        88  88aaaaaa8P'  88
# 88"""""  `8b     d8'  88  88  88        88  88""""88'    88      v2.0
# 88        `8b   d8'   88  88  88        88  88    `8b    88
# 88         `8b,d8'    88  88  Y8a.    .a8P  88     `8b   88
# 88888888888  "8"      88  88   `"Y8888Y"'   88      `8b  88888888
#
# 			 [ UNDEADSEC from BRAZIL ]
# -> github.com/UndeadSec
# -> youtube.com/c/UndeadSec
#
# How to use:
#
#  Insert name: example
#  Insert level domain: .com
#
# Select an option:
#
# [1] Generate evil urls
# [2] Detect evil urls
#
# >>> 1
#
# 88888888888           88  88  88        88  88888888ba   88
# 88                    ""  88  88        88  88      "8b  88
# 88                        88  88        88  88      ,8P  88
# ...

# %%
% cd /content/
# Out:
# /content

# %%
! git clone https://github.com/phishai/idn_generator.git
# Out:
# Cloning into 'idn_generator'...
# remote: Enumerating objects: 24, done.
# remote: Total 24 (delta 0), reused 0 (delta 0), pack-reused 24
# Unpacking objects: 100% (24/24), done.

# %%
% cd /content/idn_generator
# Out:
# /content/idn_generator

# %%
! python main.py facebook .com --punycode
# Out:
# xn--acebook-js3c.com,xn--acebook-js3c.com,xn--acebook-w1b.com,xn--acebook-w1b.com,xn--acebook-2m2c.com,xn--acebook-nr2c.com,xn--acebook-vx2z.com,facebook.com,facebook.com,xn--fcebook-hwa.com,xn--fcebook-8va.com,xn--fcebook-pwa.com,xn--fcebook-ngc.com,xn--fcebook-83a.com,xn--fcebook-xwa.com,xn--fcebook-qn4c.com,xn--fcebook-z0c.com,xn--fcebook-9m4c.com,xn--fcebook-5wa.com,xn--fcebook-exa.com,xn--fcebook-pl3c.com,xn--fcebook-s3a.com,xn--fcebook-p4a.com,xn--fcebook-nu2c.com,xn--fcebook-rn7e.com,xn--fcebook-bsc.com,xn--fcebook-6n4c.com,xn--fcebook-no4c.com,xn--fcebook-kp4c.com,xn--fcebook-3o4c.com,xn--fcebook-0p4c.com,xn--fcebook-hq4c.com,xn--fcebook-xq4c.com,xn--fcebook-ur4c.com,xn--fcebook-er4c.com,xn--fcebook-bs4c.com,xn--fcebook-xqc.com,xn--fcebook-zkc.com,xn--fcebook-jkc.com,xn--fcebook-bsc.com,xn--fcebook-rsc.com,xn--fcebook-lbd.com,xn--faebook-64a.com,xn--faebook-64a.com,xn--faebook-n5a.com,xn--faebook-n5a.com,xn--faebook-k6a.com,xn--faebook-k6a.com,xn--faebook-35a.com,xn--faebook-
# ...

# %% [markdown]
# https://github.com/phishai/idn_generator

# %% [markdown]
# https://github.com/UndeadSec/EvilURL
