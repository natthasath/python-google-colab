# %% [markdown]
# # Mesh Tensorflow

# %% [markdown]
# การวิเคราะห์ปัญญาประดิษฐ์แบบกระจายศูนย์ ( Distributed Deep Learning ) ด้วย Mesh Tensorflow มาใช้ในการประมวลผลแบบ Data Parallelism และ Model Parallelism ที่ข้อมูลมีขนาดใหญ่ อย่างเช่น Model ที่มีขนาด 5 พันล้าน Parameter พวก [3D Model](https://github.com/tensorflow/mesh/blob/master/mesh_tensorflow/experimental/unet.py) โดยจะใช้เทคนิค Batch Splitting

# %%
from IPython.display import YouTubeVideo
YOUTUBE_ID = 'HgGyWS40g-g'
YouTubeVideo(YOUTUBE_ID)

# %%
! pip install mesh-tensorflow

# %%
! git clone https://github.com/tensorflow/mesh.git
# Out:
# fatal: destination path 'mesh' already exists and is not an empty directory.

# %%
% cd /content/mesh/examples/
# Out:
# /content/mesh/examples

# %% [markdown]
# ## Fix Code
# หากทำการ Run แล้วเกิด Error เนื่องจากไม่สามารถใช้คำสั่ง Mesh Tensorflow ได้ ให้ทำการ Upgrade Tensorflow https://colab.research.google.com/notebooks/tensorflow_version.ipynb#scrollTo=kzTSf5QCfXhI

# %%
! python mnist.py
# Out:
# Streaming output truncated to the last 5000 lines.
# 2020-03-08 03:13:35.285579: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2020-03-08 03:13:35.285605: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-03-08 03:13:35.285685: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-08 03:13:35.286306: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-08 03:13:35.286803: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1746] Adding visible gpu devices: 0
# ...

# %% [markdown]
# https://github.com/tensorflow/mesh
