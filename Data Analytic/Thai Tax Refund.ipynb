# %% [markdown]
# # Thai Tax Refund

# %% [markdown]
# การตรวจสอบสถานะการยื่นแบบภาษี ( Tax Refund ) โดยใช้เลขบัตรประขาขน ชื่อ นามสกุล ในการตรวจสอบสถานะการยื่นแบบ

# %%
! pip install thaitaxrefund
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
! thaitaxrefund 1111111111111 บิ๊ก ตู่
# Out:
# ยื่นแบบฯ

# %%
import thaitaxrefund

thai_id = '1111111111111'
thai_name = 'บิ๊ก'
thai_surname = 'ตู่'
thaitaxrefund.check(thai_id, thai_name, thai_surname, thai_year=2562)
# Out:
# {'code': 'SYS001',
#  'countByName': 0,
#  'countByNameNid': 0,
#  'countByNid': 0,
#  'criteria': {'dln': '',
#   'fName': 'บิ๊ก',
#   'formCode': '',
#   'lName': 'ตู่',
#   'mName': '',
#   'nid': '1111111111111',
#   'taxYear': '2562',
#   'tin': '',
#   'txpTtlText': ''},
#  'formData': {'dln': '',
#   'fName': 'บิ๊ก',
#   'formCode': '',
#   'lName': 'ตู่',
#   'mName': '',
#   'nid': '1111111111111',
#   'taxYear': '',
#   'tin': '',
#   'txpTtlText': ''},
#  'formDetailList': [],
#  'formSendDocDetail': None,
#  'ipAddress': '104.196.39.252',
#  'message': 'เกิดความขัดข้องในระบบ กรุณาเข้ามาใหม่ภายหลัง',
#  'messageEN': 'Process fail.',
#  'processPicName': 'process_1',
#  'reqDoc': False,
#  'reqNewK39': False,
#  'saveEvaluate': False,
#  'searchPromptPay': False,
#  'uploadConsiderDoc': False,
#  'uploadDoc': False,
#  'urlReqNewK39': '',
#  'urlSearchPromptPay': '',
#  'urlUploadDocument': '',
#  'process_text': 'ยื่นแบบฯ'}

# %% [markdown]
# https://github.com/kittinan/thai-tax-refund
